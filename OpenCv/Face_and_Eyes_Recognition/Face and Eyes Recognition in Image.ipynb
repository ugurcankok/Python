# %%
import cv2
import numpy as np

# %%
face=cv2.CascadeClassifier("/Users/ugurcan/Desktop/haarcascades/haarcascade_frontalface_default.xml")
eye=cv2.CascadeClassifier("/Users/ugurcan/Desktop/haarcascades/haarcascade_eye.xml")

# %%
image=cv2.imread("/Users/ugurcan/Desktop/opencv/face.jpg")

# %%
img_gray=cv2.cvtColor(image,cv2.COLOR_BGR2GRAY)
faces=face.detectMultiScale(img_gray,1.1,8)
for (x,y,w,h) in faces: 
    cv2.rectangle(image,(x,y),(x+w,y+h),(255,0,0),2)
    face_area=image[y:y+h,x:x+w]
    gray_face=cv2.cvtColor(face_area,cv2.COLOR_BGR2GRAY)
    eyes=eye.detectMultiScale(gray_face,1.1,8)
    for (a,b,c,d) in eyes:
        cv2.rectangle(face_area,(a,b),(a+c,b+d),(0,255,0),1)
cv2.imshow("resim",image)

cv2.waitKey(0)
cv2.destroyAllWindows()
