# %%
import cv2
import numpy as np

# %%
def main():
    img1=cv2.imread("/Users/ugurcan/Desktop/image/ugurcan.jpg")
    iki_kat=cv2.pyrUp(img1)
    ikikat_kucuk=cv2.pyrDown(img1)
    cv2.imshow("resim",img1)
    cv2.waitKey(0)
    cv2.destroyAllWindows

# %%
if __name__=="__main__":
    main()
